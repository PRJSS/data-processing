# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.manifold import TSNE
import numpy as np

# %%
data = pd.read_csv("creditcard.csv", thousands = ",")

# %%
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
dataset = data

# %%
def tsne_plot(X, y):
    tsne = TSNE(n_components=2)
    X_transformed = tsne.fit_transform(X)
    plt.figure(figsize=(12, 8))
    plt.scatter(
        X_transformed[np.where(y == 0), 0],
        X_transformed[np.where(y == 0), 1],
        marker='o',
        color='g',
        linewidth=1,
        alpha=0.8
    )
    plt.scatter(
        X_transformed[np.where(y == 1), 0],
        X_transformed[np.where(y == 1), 1],
        marker='o',
        color='r',
        linewidth=1,
        alpha=0.8
    )
    plt.show()

# %% [markdown]
# ## С разделениям на часы

# %%
dataset_hour = dataset
dataset_hour['Time'] = dataset["Time"].apply(lambda x : x / 3600 % 24)

# %%
anomaly_entries = dataset_hour[dataset_hour['Class'] == 1]
regular_entries = dataset_hour[dataset_hour['Class'] == 0]
subsample_size = 2000
regular_sample = regular_entries.sample(n=subsample_size)
dataset_subsample = anomaly_entries.append(regular_sample)
X_subsample = dataset_subsample.drop(columns=['Class']).values
y_subsample = dataset_subsample['Class'].values
tsne_plot(X_subsample, y_subsample)
# Out:
# /var/folders/jq/1l3r6pcn17lglysrw1rgw3yc0000gn/T/ipykernel_33958/1955657344.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset_subsample = anomaly_entries.append(regular_sample)
# /usr/local/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
X = regular_entries.drop(columns="Class")

# %%
from tensorflow.keras import layers, losses, metrics, optimizers, regularizers
from tensorflow.keras.models import Model
input_layer = layers.Input(shape=(X.shape[1],))
encoded = layers.Dense(100, activation='tanh')(input_layer)
encoded = layers.Dense(50, activation='relu')(encoded)
decoded = layers.Dense(50, activation='tanh')(encoded)
decoded = layers.Dense(100, activation='tanh')(decoded)
output_layer = layers.Dense(X.shape[1], activation='relu')(decoded)
autoencoder = Model(input_layer, output_layer)
autoencoder.compile(
    optimizer='adadelta', loss='mse', metrics=['accuracy']
)
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 30)]              0
#
#  dense (Dense)               (None, 100)               3100
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 50)                2550
#
#  dense_3 (Dense)             (None, 100)               5100
#
#  dense_4 (Dense)             (None, 30)                3030
#
# =================================================================
# Total params: 18,830
# Trainable params: 18,830
# Non-trainable params: 0
# _________________________________________________________________
# 2022-06-01 11:48:13.737250: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
autoencoder.fit(X, X,
                batch_size = 256, epochs = 10,
                shuffle = True, validation_split = 0.20)
# Out:
# Epoch 1/10
# 889/889 [==============================] - 3s 3ms/step - loss: 2370.1995 - accuracy: 0.1023 - val_loss: 2269.2913 - val_accuracy: 0.4623
# Epoch 2/10
# 889/889 [==============================] - 3s 3ms/step - loss: 2361.1211 - accuracy: 0.6237 - val_loss: 2258.1526 - val_accuracy: 0.4836
# Epoch 3/10
# 889/889 [==============================] - 2s 2ms/step - loss: 2343.8728 - accuracy: 0.6342 - val_loss: 2239.7332 - val_accuracy: 0.4836
# Epoch 4/10
# 889/889 [==============================] - 2s 3ms/step - loss: 2323.9768 - accuracy: 0.6341 - val_loss: 2222.7209 - val_accuracy: 0.4835
# Epoch 5/10
# 889/889 [==============================] - 3s 3ms/step - loss: 2308.9202 - accuracy: 0.6352 - val_loss: 2210.4724 - val_accuracy: 0.4903
# Epoch 6/10
# 889/889 [==============================] - 3s 3ms/step - loss: 2298.2573 - accuracy: 0.7368 - val_loss: 2201.8252 - val_accuracy: 0.7387
# Epoch 7/10
# 889/889 [==============================] - 3s 3ms/step - loss: 2290.3381 - accuracy: 0.8442 - val_loss: 2195.3127 - val_accuracy: 0.8218
# Epoch 8/10
# 889/889 [==============================] - 3s 3ms/step - loss: 2283.9644 - accuracy: 0.8779 - val_loss: 2190.0884 - val_accuracy: 0.8712
# Epoch 9/10
# 889/889 [==============================] - 2s 3ms/step - loss: 2278.7085 - accuracy: 0.8956 - val_loss: 2185.8132 - val_accuracy: 0.8979
# Epoch 10/10
# 889/889 [==============================] - 3s 3ms/step - loss: 2274.2256 - accuracy: 0.9090 - val_loss: 2182.1462 - val_accuracy: 0.9165

# %%
y_all = dataset_hour['Class']
X_all = dataset_hour.drop(columns = 'Class')

# %%
from tensorflow.keras.models import Sequential
autoencoder_encode = Sequential()
autoencoder_encode.add(autoencoder.layers[0])
autoencoder_encode.add(autoencoder.layers[1])
autoencoder_encode.add(autoencoder.layers[2])
X_encoded = autoencoder_encode.predict(X_all)

# %%
X_encoded.shape
# Out:
# (284807, 50)

# %%
y_all.shape
# Out:
# (284807,)

# %%
df = pd.DataFrame(X_encoded)

# %%
df['Class'] = y_all

# %%
df
# Out:
#           0         1         2         3         4         5        6  \
# 0       0.0  2.031799  0.028990  1.851513  2.013241  4.380721  0.00000
# 1       0.0  0.543713  0.292494  0.419468  0.811626  1.262709  0.00000
# 2       0.0  2.210564  0.000000  1.777172  2.130795  4.279499  0.00000
# 3       0.0  2.336591  0.120785  1.829079  1.779768  4.229074  0.00000
# 4       0.0  2.101726  0.000000  1.783733  2.096034  4.202409  0.00000
# ...     ...       ...       ...       ...       ...       ...      ...
# 284802  0.0  0.000000  0.565471  0.644366  0.000000  0.000000  0.00000
# 284803  0.0  0.703444  0.460044  1.399275  0.000000  1.154530  0.00000
# 284804  0.0  1.419315  0.351231  1.413867  1.198076  4.509110  0.00000
# 284805  0.0  0.031197  1.073001  1.289148  0.000000  0.000000  1.07771
# 284806  0.0  1.762738  0.129984  1.772414  1.649162  4.584350  0.00000
#
#                7         8         9  ...        41        42        43   44  \
# 0       0.460019  2.545230  4.451500  ...  0.316681  2.134819  0.000000  0.0
# 1       0.336967  1.172161  0.609434  ...  0.000000  0.442298  0.000000  0.0
# 2       0.566729  2.444287  4.322381  ...  0.314490  2.095310  0.000000  0.0
# 3       0.435568  2.658762  4.345755  ...  0.292385  2.383136  0.000000  0.0
# 4       0.560074  2.456677  4.331202  ...  0.294445  2.085203  0.000000  0.0
# ...          ...       ...       ...  ...       ...       ...       ...  ...
# 284802  0.000000  0.710096  0.000000  ...  1.031519  0.000000  1.389884  0.0
# 284803  0.000000  2.533894  2.609794  ...  0.130868  0.778537  0.000000  0.0
# 284804  0.000000  3.111576  4.380589  ...  0.024676  2.278180  0.000000  0.0
# 284805  0.000000  1.850528  1.189025  ...  0.000000  0.000000  0.240994  0.0
# 284806  0.223845  2.763064  4.629753  ...  0.316314  2.261575  0.000000  0.0
#
#               45   46        47        48        49  Class
# 0       0.702580  0.0  3.868605  2.952289  1.916784      0
# 1       0.000000  0.0  1.487720  1.052475  1.080615      0
# 2       0.792257  0.0  3.780650  3.097649  1.737687      0
# 3       0.855358  0.0  4.044794  3.297369  1.921683      0
# 4       0.819383  0.0  3.765597  3.058803  1.791944      0
# ...          ...  ...       ...       ...       ...    ...
# 284802  1.740254  0.0  0.000000  0.000000  0.000000      0
# 284803  0.537589  0.0  1.059839  0.825624  1.380553      0
# 284804  0.906852  0.0  3.463619  2.633456  1.833524      0
# 284805  0.867998  0.0  0.000000  0.000000  1.237028      0
# 284806  0.759078  0.0  3.967488  2.837410  2.111523      0
#
# [284807 rows x 51 columns]

# %%
anomaly_entries = df[df['Class'] == 1]
regular_entries = df[df['Class'] == 0]
subsample_size = 2000
regular_sample = regular_entries.sample(n=subsample_size)
dataset_subsample = anomaly_entries.append(regular_sample)
X_subsample = dataset_subsample.drop(columns=['Class']).values
y_subsample = dataset_subsample['Class'].values
tsne_plot(X_subsample, y_subsample)
# Out:
# /var/folders/jq/1l3r6pcn17lglysrw1rgw3yc0000gn/T/ipykernel_33958/1149759380.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset_subsample = anomaly_entries.append(regular_sample)
# /usr/local/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
df
# Out:
#           0         1         2         3         4         5        6  \
# 0       0.0  2.031799  0.028990  1.851513  2.013241  4.380721  0.00000
# 1       0.0  0.543713  0.292494  0.419468  0.811626  1.262709  0.00000
# 2       0.0  2.210564  0.000000  1.777172  2.130795  4.279499  0.00000
# 3       0.0  2.336591  0.120785  1.829079  1.779768  4.229074  0.00000
# 4       0.0  2.101726  0.000000  1.783733  2.096034  4.202409  0.00000
# ...     ...       ...       ...       ...       ...       ...      ...
# 284802  0.0  0.000000  0.565471  0.644366  0.000000  0.000000  0.00000
# 284803  0.0  0.703444  0.460044  1.399275  0.000000  1.154530  0.00000
# 284804  0.0  1.419315  0.351231  1.413867  1.198076  4.509110  0.00000
# 284805  0.0  0.031197  1.073001  1.289148  0.000000  0.000000  1.07771
# 284806  0.0  1.762738  0.129984  1.772414  1.649162  4.584350  0.00000
#
#                7         8         9  ...        41        42        43   44  \
# 0       0.460019  2.545230  4.451500  ...  0.316681  2.134819  0.000000  0.0
# 1       0.336967  1.172161  0.609434  ...  0.000000  0.442298  0.000000  0.0
# 2       0.566729  2.444287  4.322381  ...  0.314490  2.095310  0.000000  0.0
# 3       0.435568  2.658762  4.345755  ...  0.292385  2.383136  0.000000  0.0
# 4       0.560074  2.456677  4.331202  ...  0.294445  2.085203  0.000000  0.0
# ...          ...       ...       ...  ...       ...       ...       ...  ...
# 284802  0.000000  0.710096  0.000000  ...  1.031519  0.000000  1.389884  0.0
# 284803  0.000000  2.533894  2.609794  ...  0.130868  0.778537  0.000000  0.0
# 284804  0.000000  3.111576  4.380589  ...  0.024676  2.278180  0.000000  0.0
# 284805  0.000000  1.850528  1.189025  ...  0.000000  0.000000  0.240994  0.0
# 284806  0.223845  2.763064  4.629753  ...  0.316314  2.261575  0.000000  0.0
#
#               45   46        47        48        49  Class
# 0       0.702580  0.0  3.868605  2.952289  1.916784      0
# 1       0.000000  0.0  1.487720  1.052475  1.080615      0
# 2       0.792257  0.0  3.780650  3.097649  1.737687      0
# 3       0.855358  0.0  4.044794  3.297369  1.921683      0
# 4       0.819383  0.0  3.765597  3.058803  1.791944      0
# ...          ...  ...       ...       ...       ...    ...
# 284802  1.740254  0.0  0.000000  0.000000  0.000000      0
# 284803  0.537589  0.0  1.059839  0.825624  1.380553      0
# 284804  0.906852  0.0  3.463619  2.633456  1.833524      0
# 284805  0.867998  0.0  0.000000  0.000000  1.237028      0
# 284806  0.759078  0.0  3.967488  2.837410  2.111523      0
#
# [284807 rows x 51 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_all,
test_size=0.2, shuffle=True, stratify = y_all)

# %%
X_train.shape
# Out:
# (227845, 50)

# %%
X_test.shape
# Out:
# (56962, 50)

# %%
y_train.shape
# Out:
# (227845,)

# %%
y_test.shape
# Out:
# (56962,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(random_state=0, max_iter = 1000).fit(X_train, y_train)

# %%
predict = clf.predict(X_test)

# %%
predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_test
# Out:
# 205047    0
# 221521    0
# 116326    0
# 179055    0
# 31242     0
#          ..
# 218416    0
# 256171    0
# 239884    0
# 120159    0
# 142435    0
# Name: Class, Length: 56962, dtype: int64

# %%
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score)

print(accuracy_score(y_test, predict))
print(precision_score(y_test, predict,  average='macro', zero_division=1))
print(recall_score(y_test, predict, average='weighted'))
print(f1_score (y_test, predict,  average='weighted'))
# Out:
# 0.9989817773252344
# 0.9281321075859437
# 0.9989817773252344
# 0.9988431167252005

# %% [markdown]
# ## Вторая часть

# %%
from sklearn.neighbors import LocalOutlierFactor

# %%
lof = LocalOutlierFactor(n_neighbors=20, contamination=0.1)

# %%
lof.fit(X_all)
# Out:
# LocalOutlierFactor(contamination=0.1)

# %%
y_lof = lof.predict(X_all) == -1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [37], in <module>
# ----> 1 y_lof = lof.predict(X_all) == -1
#
# File /usr/local/lib/python3.9/site-packages/sklearn/utils/metaestimators.py:127, in _AvailableIfDescriptor.__get__(self, obj, owner)
#     121 attr_err = AttributeError(
#     122     f"This {repr(owner.__name__)} has no attribute {repr(self.attribute_name)}"
#     123 )
#     124 if obj is not None:
#     125     # delegate only on instances, not the classes.
#     126     # this is to allow access to the docstrings.
# --> 127     if not self.check(obj):
#     128         raise attr_err
#     129     out = MethodType(self.fn, obj)
#
# File /usr/local/lib/python3.9/site-packages/sklearn/neighbors/_lof.py:326, in LocalOutlierFactor._check_novelty_predict(self)
#     319 if not self.novelty:
#     320     msg = (
#     321         "predict is not available when novelty=False, use "
#     322         "fit_predict if you want to predict on training data. Use "
#     323         "novelty=True if you want to use LOF for novelty detection "
#     324         "and predict on new unseen data."
#     325     )
# --> 326     raise AttributeError(msg)
#     327 return True
#
# AttributeError: predict is not available when novelty=False, use fit_predict if you want to predict on training data. Use novelty=True if you want to use LOF for novelty detection and predict on new unseen data.

# %%
print(accuracy_score(y_subsample, y_lof))
print(precision_score(y_subsample, y_lof,  average='macro', zero_division=1))
print(recall_score(y_subsample, y_lof, average='weighted'))
print(f1_score (y_subsample, y_lof,  average='weighted'))
