# %% [markdown]
# Вариант 2. Решить задачу с помощью Метода опорных векторов / Нейронными сетями прямого распространения

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv ('data-processing/lab1/water_potability.csv')
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
#df = df.drop(columns=['ph', 'Sulfate', 'Trihalomethanes'])
df.fillna(df.mean(), inplace=True)

# %%
#sns.set_theme(style="ticks")
#sns.pairplot(df.dropna())

# %%
df.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
>>> from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
       'Organic_carbon', 'Trihalomethanes', 'Turbidity']] = scaler.fit_transform(df[['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
       'Organic_carbon', 'Trihalomethanes', 'Turbidity']])
df
# Out:
#             ph  Hardness    Solids  Chloramines   Sulfate  Conductivity  \
# 0     0.505771  0.571139  0.336096     0.543891  0.680385      0.669439
# 1     0.265434  0.297400  0.300611     0.491839  0.581699      0.719411
# 2     0.578509  0.641311  0.321619     0.698543  0.581699      0.414652
# 3     0.594055  0.605536  0.356244     0.603314  0.647347      0.317880
# 4     0.649445  0.484851  0.289922     0.484900  0.514545      0.379337
# ...        ...       ...       ...          ...       ...           ...
# 3271  0.333436  0.530482  0.775947     0.533436  0.656047      0.603192
# 3272  0.557775  0.530016  0.279263     0.603473  0.581699      0.368912
# 3273  0.672822  0.465486  0.539101     0.547807  0.581699      0.438152
# 3274  0.366197  0.664407  0.191490     0.465860  0.581699      0.387157
# 3275  0.562477  0.535635  0.280484     0.560259  0.581699      0.255266
#
#       Organic_carbon  Trihalomethanes  Turbidity  Potability
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns='Potability'), df['Potability'], stratify=df['Potability'], random_state=1)

# %%
from sklearn.neural_network import MLPClassifier

# %%
clf = MLPClassifier(random_state=1, max_iter=1000).fit(X_train, y_train)

# %%
clf.predict_proba(X_test)
# Out:
# array([[0.67469555, 0.32530445],
#        [0.66794762, 0.33205238],
#        [0.77128209, 0.22871791],
#        ...,
#        [0.60671711, 0.39328289],
#        [0.82889081, 0.17110919],
#        [0.08343622, 0.91656378]])

# %%
clf.score(X_test, y_test)
# Out:
# 0.6996336996336996
